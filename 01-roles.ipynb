# %%
from dotenv import load_dotenv
from groq import Groq
import os
load_dotenv()

client = Groq(
    api_key=os.environ.get("GROQ_API"),  # This is the default and can be omitted
)

# %% [markdown]
# ### Compreendendo os Roles

# %% [markdown]
# - User: Mensagem do usuário
# - Assistant: Resposta do modelo
# - System: Instruções de comportamento para o modelo

# %%
chat_completion = client.chat.completions.create(
    messages=[
        {
            "role": "user",
            "content": "Me explique de forma reduzida o que são as LLMs",
        }
    ],
    model="llama-3.3-70b-versatile",
)
print(chat_completion.choices[0].message.content)
# Out:
# As **LLMs (Large Language Models)** são modelos de inteligência artificial treinados com enormes quantidades de texto para aprender padrões da linguagem humana. Eles usam arquiteturas de redes neurais, geralmente do tipo **Transformer**, que permitem processar e gerar texto de forma coerente e contextualizada.
#
# - **Escala**: possuem bilhões a trilhões de parâmetros, o que aumenta sua capacidade de capturar nuances linguísticas.
# - **Treinamento**: aprendem de forma não supervisionada, prevendo a próxima palavra em frases de vastos corpora (livros, artigos, sites, etc.).
# - **Uso**: são a base de assistentes de texto, chatbots, tradutores automáticos, resumidores, geradores de código, entre outras aplicações.
#
# Em resumo, LLMs são “cérebro” de IA que, a partir de muito texto, conseguem entender e produzir linguagem natural de forma impressionante.

# %% [markdown]
# ### Definindo um comportamento para modelo

# %%
chat_completion = client.chat.completions.create(
    messages=[
        {
            "role": "system",
            "content": "Você é um especialista em IA que responde de forma clara e objetiva."
        },
        {
            "role": "user",
            "content": "Me explique de forma reduzida o que são as LLMs",
        }
    ],
    model="llama-3.3-70b-versatile",
)
print(chat_completion.choices[0].message.content)
# Out:
# As **LLMs (Large Language Models)** são modelos de inteligência artificial baseados em redes neurais muito grandes, treinados com enormes volumes de texto (bilhões de palavras). Esse treinamento permite que eles:
#
# 1. **Aprendam padrões linguísticos** – gramática, vocabulário, estilo e relações semânticas.
# 2. **Entendam contexto** – analisam sequências de palavras para captar o sentido de frases e parágrafos.
# 3. **Gerem texto** – produzem respostas, resumos, traduções, códigos, entre outros, de forma coerente e fluente.
#
# Em resumo, uma LLM é um modelo de IA que, a partir de vastos dados textuais, consegue compreender e gerar linguagem natural para diversas aplicações.

# %% [markdown]
# ### Controlando Resposta do Modelo

# %%
chat_completion = client.chat.completions.create(
    messages=[
        {
            "role": "system",
            "content": "Você é um especialista em IA que responde de forma clara e objetiva."
        },
        {
            "role": "user",
            "content": "Explique a importância de LLMs com baixa latência."
        },
        {
            "role": "assistant",
            "content": "LLMs com baixa latência permitem respostas mais rápidas, o que melhora a experiência do usuário."
        },
        {
            "role": "user",
            "content": "Pode dar exemplos de aplicações práticas?"
        }
    ],
    model="llama-3.3-70b-versatile",
)

print(chat_completion.choices[0].message.content)
# Out:
# **Exemplos de aplicações práticas que exigem LLMs de baixa latência**
#
# | Área | Aplicação | Por que a latência baixa é crítica |
# |------|-----------|------------------------------------|
# | **Assistentes virtuais** | Chatbots de suporte ao cliente, assistentes de voz (Alexa, Google Assistant) | Respostas quase instantâneas mantêm a conversa fluida e evitam frustração do usuário. |
# | **Ferramentas de produtividade** | Autocompletar de código (Copilot, Tabnine), sugestões de texto em editores de documentos | O desenvolvedor ou escritor espera que a sugestão apareça enquanto digita; atrasos > 200 ms quebram a sensação de “assistência em tempo real”. |
# | **Finanças e trading** | Análise de notícias, geração de resumos de relatórios, alertas de risco | Decisões de compra/venda são tomadas em frações de segundo; um atraso pode significar perdas financeiras. |
# | **Jogos e realidade aumentada/virtual** | NPCs que conversam, geração dinâmica de diálogos ou descrições de cenas | A imersão depende de respostas que acompanhem o ritmo do jogo; latência perceptível quebra a experiência. |
# | **Saúde** | Sistemas de triagem de sintomas, apoio a médicos com sugestões de diagnóstico durante consultas | O profissional precisa da informação imediatamente para tomar decisões clínicas. |
# | **E‑commerce** | Busca semântica e recomendação de produtos enquanto o usuário digita | Um retorno rápido aumenta a taxa de conversão; atrasos levam o cliente a abandonar a busca. |
# | **Operações industriais** | Interfaces homem‑máquina que interpretam comandos de linguagem natural para controlar maquinário | Respostas em tempo real evitam interrupções na linha de produção. |
# | **Segurança e monitoramento** | Análise em tempo real de logs ou transcrições de chamadas para detectar ameaças | Cada segundo conta para bloquear um ataque ou responder a um incidente. |
# | **Educação** | Tutores virtuais que respondem a dúvidas de estudantes em tempo real | A aprendizagem é mais eficaz quando o estudante não precisa esperar para receber explicações. |
# | **Mobilidade** | Sistemas de navegação que aceitam comandos de voz e dão instruções contextuais | O motorista precisa de respostas rápidas para não desviar a atenção da estrada. |
#
# ### Por que a latência importa?
# 1. **Experiência do usuário** – Latência > 300 ms já é percebida como “lenta” em interações humanas.
# 2. **Decisões em tempo real** – Em finanças, saúde e controle industrial, cada milissegundo pode ter impacto direto no resultado.
# 3. **Escalabilidade** – Serviços com baixa latência podem atender mais requisições simultâneas sem degradar a qualidade.
# 4. **Competitividade** – Produtos que respondem instantaneamente ganham vantagem no mercado frente a concorrentes mais lentos.
#
# ### Estratégias para alcançar baixa latência
# - **Modelos compactos** (distilação, quantização, pruning).
# - **Inferência em hardware especializado** (TPU, GPU de baixa latência, ASICs).
# - **Cache de respostas** para consultas frequentes ou padrões.
# - **Arquitetura de microsserviços** com pipelines de pré‑processamento otimizados.
# - **Edge computing** – executar o modelo próximo ao usuário para reduzir o tempo de ida/volta da rede.
#
# Esses exemplos ilustram como a baixa latência deixa os LLMs viáveis em cenários onde a rapidez da informação é tão importante quanto a qualidade da resposta.

# %% [markdown]
# ### Usando System Prompt Refinados

# %%
chat_completion = client.chat.completions.create(
    messages=[
        {
            "role": "system",
            "content": (
                "Você é um especialista em Inteligência Artificial focado em explicar conceitos "
                "de forma clara, estruturada e prática. Sempre inicie suas respostas com um "
                "resumo em até 3 linhas, depois detalhe com exemplos reais e aplicações no mundo "
                "dos negócios e tecnologia. Evite termos excessivamente técnicos sem explicação "
                "e, quando necessário, use analogias simples. "
                "Se o usuário pedir código, forneça exemplos em Python bem comentados."
            ),
        },
        {
            "role": "user",
            "content": "Explique a importância de LLMs com baixa latência."
        }
    ],
    model="llama-3.3-70b-versatile",
)

print(chat_completion.choices[0].message.content)
# Out:
# **Resumo (até 3 linhas)**
# LLMs (Large Language Models) com baixa latência respondem rapidamente, o que melhora a experiência do usuário, permite decisões em tempo real e reduz custos operacionais. Em ambientes críticos, como atendimento ao cliente ou sistemas de controle, a rapidez é tão importante quanto a precisão.
#
# ---
#
# ## Por que a latência baixa é crucial?
#
# | Aspecto | Como a baixa latência impacta | Exemplo real |
# |---------|------------------------------|--------------|
# | **Experiência do usuário** | Respostas quase instantâneas mantêm o usuário engajado e evitam frustração. | Chatbots de suporte que respondem em < 200 ms evitam que o cliente abandone a conversa. |
# | **Tomada de decisão em tempo real** | Em finanças, segurança ou manufatura, decisões precisam ser feitas em milissegundos. | Algoritmos de trading que usam LLMs para interpretar notícias e gerar ordens de compra/venda em < 100 ms. |
# | **Escalabilidade e custos** | Menor tempo de processamento libera recursos de CPU/GPU, permitindo mais chamadas simultâneas com o mesmo hardware. | Serviços de tradução automática que atendem a milhões de requisições por dia usando menos servidores. |
# | **Conformidade regulatória** | Em setores como saúde, respostas rápidas podem ser exigidas por normas de tempo de atendimento. | Sistemas de triagem de sintomas que dão recomendações imediatas ao paciente, dentro dos limites de SLA. |
# | **Integração com dispositivos edge** | Dispositivos com recursos limitados (smartphones, IoT) precisam de respostas rápidas e de baixo consumo de energia. | Assistentes de voz embarcados em carros que processam comandos em < 150 ms para evitar atrasos na condução. |
#
# ---
#
# ## Como a latência se relaciona com a arquitetura dos LLMs
#
# 1. **Tamanho do modelo vs. velocidade** – Modelos menores (por exemplo, 1B parâmetros) são naturalmente mais rápidos que modelos de 70B, mas podem perder alguma nuance.
# 2. **Quantização e poda** – Reduzir a precisão dos pesos (int8, float16) diminui o tempo de cálculo sem degradar muito a qualidade.
# 3. **Inferência em hardware especializado** – GPUs de última geração, TPUs ou chips de inferência (como o NVIDIA LLM Accelerator) podem cortar a latência pela metade.
# 4. **Cache de prompts** – Reutilizar partes estáticas de um prompt (ex.: instruções de sistema) evita recomputação desnecessária.
# 5. **Pipeline assíncrono** – Dividir a tarefa em pré‑processamento, inferência e pós‑processamento permite que cada etapa seja paralelizada.
#
# ---
#
# ## Aplicações de negócios que dependem de baixa latência
#
# ### 1. Atendimento ao cliente 24/7
# - **Problema:** Clientes esperam respostas em segundos, não em minutos.
# - **Solução:** Deploy de um LLM quantizado em um cluster de GPUs com balanceamento de carga, garantindo < 200 ms por resposta.
# - **Resultado:** Taxa de abandono de chat reduzida em 30 %, aumento da satisfação (NPS) em 12 pontos.
#
# ### 2. Finanças e trading algorítmico
# - **Problema:** Notícias ou relatórios econômicos devem ser analisados em tempo real para capturar oportunidades de mercado.
# - **Solução:** LLM leve (ex.: GPT‑Neo 1.3B) rodando em CPUs de alta frequência, integrados a pipelines de streaming de dados.
# - **Resultado:** Estratégia captura 5 % a mais de lucro anual em comparação com modelos com latência > 500 ms.
#
# ### 3. Sistemas de recomendação em e‑commerce
# - **Problema:** Usuário adiciona um item ao carrinho e espera recomendações imediatas.
# - **Solução:** LLM de geração de texto para criar descrições de produtos em tempo real, servido via API com < 150 ms.
# - **Resultado:** Aumento de 8 % nas taxas de upsell, porque a recomendação chega antes que o cliente perca o interesse.
#
# ### 4. Assistentes de voz embarcados (automotivo, doméstico)
# - **Problema:** Latência alta cria “eco” perceptível e pode ser perigoso em veículos.
# - **Solução:** Modelos otimizados (ONNX + int8) rodando em chip de inferência local, com resposta em < 100 ms.
# - **Resultado:** Experiência fluida, aceitação do usuário superior a 90 % em testes de usabilidade.
#
# ### 5. Monitoramento e alerta em IoT
# - **Problema:** Sensores enviam dados críticos que precisam ser interpretados instantaneamente (ex.: falhas em máquinas).
# - **Solução:** LLM pequeno integrado ao gateway IoT para classificar eventos em < 50 ms antes de enviar alertas ao operador.
# - **Resultado:** Redução de 40 % no tempo médio de reparo (MTTR).
#
# ---
#
# ## Estratégias práticas para reduzir a latência
#
# 1. **Escolher o modelo certo** – Use o menor modelo que atenda ao nível de qualidade exigido.
# 2. **Aplicar quantização** – Converta pesos para int8/float16; ferramentas como `bitsandbytes` ou `TensorRT` facilitam.
# 3. **Usar compiladores de inferência** – ONNX Runtime, TensorRT, ou OpenVINO otimizam o grafo de cálculo.
# 4. **Cachear embeddings** – Quando o mesmo documento ou pergunta aparece frequentemente, reutilize o embedding pré‑calculado.
# 5. **Horizontal scaling** – Distribua as requisições entre vários nós; use load balancers que considerem a latência de cada nó.
# 6. **Monitoramento contínuo** – Métricas de latência (p99, p95) devem ser visualizadas em dashboards; ajuste automático de recursos quando picos são detectados.
#
# ---
#
# ## Conclusão
#
# A latência baixa transforma um LLM de “bom” para “essencial” em muitos cenários de negócios. Ela garante que a inteligência artificial seja percebida como parte natural e confiável dos fluxos de trabalho, permitindo melhor experiência do usuário, decisões em tempo real e custos operacionais mais baixos. Investir em otimizações de modelo, hardware adequado e arquitetura de serviço é tão importante quanto melhorar a acurácia do modelo.
