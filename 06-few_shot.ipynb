# %% [markdown]
# ### Técnicas Few Shot Prompting

# %% [markdown]
# - **Zero Shot**: Sem exemplos, apenas instruções
# - **One Shot**: Um exemplo para instruir o modelo
# - **Few Shot**: Múltiplos exemplos para melhor compreensão

# %%
from dotenv import load_dotenv
from groq import Groq
import os
load_dotenv()

client = Groq(
    api_key=os.environ.get("GROQ_API"),  # This is the default and can be omitted
)

# %% [markdown]
# ### Zero Shot Prompting

# %%
system_prompt = """
Você é um chef renomado. 
Receba o nome de um ingrediente e sugira um prato sofisticado onde ele seja protagonista.
"""

user_prompt = "Abacate"

response = client.chat.completions.create(
    model="openai/gpt-oss-120b",
    messages=[
        {"role": "system", "content": system_prompt},
        {"role": "user", "content": user_prompt}
    ],
    temperature=0.5
)

print("=== Zero Shot ===")
print("Resposta:", response.choices[0].message.content)
# Out:
# === Zero Shot ===
# Resposta: **Prato‑estrela:** *Ceviche de vieira com espuma de abacate, granita de lima‑tangerina e crocante de pistache defumado*
#
# ---
#
# ### Conceito
# O abacate assume o papel de protagonista ao transformar‑se em uma espuma aveludada que equilibra a acidez cítrica e a delicadeza da vieira. A granita de lima‑tangerina traz frescor gelado, enquanto o pistache defumado oferece contraste crocante e aromático.
#
# ---
#
# ### Ingredientes (para 4 porções)
#
# | Ingrediente | Quantidade |
# |-------------|------------|
# | Vieiras frescas (sem concha) | 12 unidades (3 por pessoa) |
# | Abacate maduro Hass | 1 grande (cerca de 200 g de polpa) |
# | Suco de limão‑tangerina (ou lima) | 60 ml |
# | Raspas de lima‑tangerina | 1 cálice |
# | Água de coco | 30 ml |
# | Sal marinho fino | a gosto |
# | Pimenta branca moída na hora | a gosto |
# | Pistache sem casca | 30 g |
# | Fumaça líquida (tipo “liquid smoke”) | 2 gotas |
# | Óleo de semente de uva | 10 ml |
# | Gengibre fresco ralado | 1 g |
# | Coentro fresco (folhas) | 4 folhas para guarnecer |
# | Flor de sal | para finalizar |
#
# ---
#
# ### Técnica passo a passo
#
# 1. **Marinar as vieiras**
#    - Tempere as vieiras com 20 ml de suco de lima‑tangerina, 1 g de gengibre ralado, sal e pimenta.
#    - Deixe em refrigeração por **8‑10 min** (não mais que 15 min para não “cozinhar” o peixe).
#
# 2. **Espuma de abacate**
#    - No liquidificador, bata a polpa do abacate com água de coco, 20 ml de suco de lima‑tangerina, sal e pimenta até ficar homogêneo.
#    - Passe a mistura por uma peneira fina (para eliminar fibras).
#    - Incorpore 1 g de lecitina de soja (opcional) e, usando um sifão de espuma, carregue com duas cápsulas de N₂O. Mantenha refrigerado.
#
# 3. **Granita de lima‑tangerina**
#    - Misture 40 ml de suco de lima‑tangerina, 10 ml de água, raspas de lima‑tangerina, açúcar fino (1 g) e uma pitada de sal.
#    - Congele em um recipiente raso; a cada 30 min, raspe com garfo para criar cristais finos. Repita até obter uma granita leve.
#
# 4. **Pistache defumado crocante**
#    - Torre levemente o pistache em uma frigideira seca (2‑3 min).
#    - Pulverize rapidamente com 2 gotas de fumaça líquida, mexa e deixe esfriar.
#    - Triture grosseiramente, mantendo alguns pedaços inteiros para textura.
#
# 5. **Montagem**
#    - Sobre um prato raso e frio, disponha 3 vieiras no centro, formando um pequeno triângulo.
#    - Regue delicadamente com o restante do suco da marinada (não usado).
#    - Sobre as vieiras, aplique **2‑3 colheres de sopa** de espuma de abacate usando o sifão.
#    - Ao redor, espalhe a granita de lima‑tangerina em fios finos ou “pó de gelo”.
#    - Salpique o pistache defumado crocante por cima e ao redor.
#    - Decore com folhas de coentro e finalize com um leve toque de flor de sal.
#
# ---
#
# ### Sugestão de harmonização
# - **Vinho:** Sauvignon Blanc (Nova Zelândia) ou um **Alvarinho** português – acidez vibrante que realça a lima‑tangerina e corta a cremosidade do abacate.
# - **Coquetel opcional:** *Gin‑tônica com infusão de pepino e manjericão*, servido em copo baixo, para reforçar a frescura do prato.
#
# ---
#
# ### Dicas do chef
#
# | Dica | Por quê? |
# |------|----------|
# | **Vieiras frescas** – escolha as que ainda têm um leve brilho translúcido; elas garantem textura “carnuda” e sabor do mar. |
# | **Abacate frio** – antes de bater, coloque a polpa no congelador por 10 min; a espuma ficará mais estável e aerada. |
# | **Granita** – não a deixe congelar totalmente; a textura de “floco de neve” deve derreter rapidamente na boca, limpando o paladar entre as mordidas. |
# | **Pistache defumado** – a fumaça deve ser sutil; o objetivo é criar um aroma que lembre madeira de macieira, sem sobrepor o delicado sabor da vieira. |
#
# ---
#
# **Resultado:** um prato que celebra o abacate em todas as suas facetas – cremosidade, frescor e elegância – ao mesmo tempo que oferece mariscos de alta qualidade, contrastes de temperatura e texturas, e um perfume sutil de fumaça. Perfeito para um jantar degustação de alto nível. Bon appétit!

# %% [markdown]
# ### One Shot Prompting

# %%
system_prompt = """
Você é um chef renomado. 
Receba o nome de um ingrediente e sugira um prato sofisticado onde ele seja protagonista.

Exemplo:
Ingrediente: Salmão
Sugestão -> Tartar de salmão fresco com molho cítrico e torradas de brioche
"""

user_prompt = "Cogumelos"

response = client.chat.completions.create(
    model="openai/gpt-oss-120b",
    messages=[
        {"role": "system", "content": system_prompt},
        {"role": "user", "content": user_prompt}
    ],
    temperature=0.5
)

print("\n=== One Shot ===")
print("Resposta:", response.choices[0].message.content)
# Out:
# === One Shot ===
# Resposta: **Ingrediente:** Cogumelos
#
# **Sugestão →** *Risoto de cogumelos silvestres com espuma de trufa negra, lascas de parmesão envelhecido e crocante de alho‑poró*
#
# Um risoto cremoso, preparado com arroz arbóreo e caldo de legumes aromatizado, que incorpora uma seleção de cogumelos silvestres (porcini, chanterelle, shiitake e melena). Finalizado com uma delicada espuma de trufa negra, lascas finas de parmesão 36‑meses e um toque crocante de alho‑poró caramelizado, o prato eleva o sabor terroso dos cogumelos a um patamar sofisticado e memorável.

# %% [markdown]
# ### Few Shot Prompting

# %%
system_prompt = """
Você é um chef renomado. 
Receba o nome de um ingrediente e sugira um prato sofisticado onde ele seja protagonista.

<exemplos>
Ingrediente: Tomate
Sugestão <-> Carpaccio de tomate com azeite trufado e manjericão fresco

Ingrediente: Chocolate
Sugestão <-> Soufflé de chocolate meio amargo com calda de frutas vermelhas

Ingrediente: Batata
Sugestão <-> Nhoque artesanal de batata ao molho de manteiga e sálvia
</exemplos>
"""

user_prompt = "Camarão"

response = client.chat.completions.create(
    model="openai/gpt-oss-120b",
    messages=[
        {"role": "system", "content": system_prompt},
        {"role": "user", "content": user_prompt}
    ],
    temperature=0.4
)

print("\n=== Few Shot ===")
print("Resposta:", response.choices[0].message.content)
# Out:
# === Few Shot ===
# Resposta: **Ingrediente:** Camarão
# **Sugestão <->** Camarão grelhado ao molho de manteiga de limão siciliano, risoto cremoso de açafrão com pérolas de tapioca e espuma de coco tostado.

# %% [markdown]
# ### Few Shot Criativo

# %%
system_prompt = """
Você é um chef criativo que mistura ingredientes improváveis em pratos sofisticados.

<Exemplos:>
Combinação: Manga + Pimenta
Prato <-> Ceviche de manga apimentado com chips de batata doce

Combinação: Café + Laranja
Prato <-> Entrecôte ao molho de café e raspas de laranja

Combinação: Queijo azul + Melancia
Prato <-> Salada refrescante de melancia com queijo azul e nozes
</exemplos>
"""

user_prompt = "Combinação: Morango + Manjericão"

response = client.chat.completions.create(
    model="openai/gpt-oss-120b",
    messages=[
        {"role": "system", "content": system_prompt},
        {"role": "user", "content": user_prompt}
    ],
    temperature=0.4
)

print("\n=== Few Shot Criativo ===")
print("Resposta:", response.choices[0].message.content)
# Out:
# === Few Shot Criativo ===
# Resposta: **Combinação:** Morango + Manjericão
#
# **Prato <->** *Tartar de Morango ao Manjericão com Crocante de Amêndoas e Redução de Vinagre Balsâmico*
#
# **Descrição:**
# Morangos frescos são finamente picados e misturados a folhas de manjericão maceradas em um leve toque de azeite de oliva extra‑virgem. A mistura é temperada com sal rosa e uma pitada de pimenta branca, então moldada em pequenos tartares. Sobre cada porção, espalha‑se um delicado crocante de amêndoas laminadas torradas, que traz contraste de textura. Finaliza‑se com um fio de redução de vinagre balsâmico envelhecido, aromatizado com raspas de limão siciliano e um leve perfume de pimenta rosa. O prato equilibra a doçura vibrante do morango, a frescura herbácea do manjericão e a acidez sutil do balsâmico, criando uma experiência sofisticada e refrescante, perfeita como entrada ou acompanhamento leve em um menu de verão.
