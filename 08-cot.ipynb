# %% [markdown]
# ## Cadeia de Pensamento

# %% [markdown]
# Útil em situações:
# - Raciocínio estruturado e explícito
# - Explicação transparente do raciocínio
# - Clareza na tomada de decisão

# %%
from dotenv import load_dotenv
from groq import Groq
import os
load_dotenv()

client = Groq(
    api_key=os.environ.get("GROQ_API"),  # This is the default and can be omitted
)

# %% [markdown]
# ### CoT para Estratégia de Marketing

# %%
system_prompt = """
Você é um estrategista de marketing que sempre usa Chain of Thoughts (CoT).
Mostre o raciocínio dentro de <cot> e depois dê uma conclusão objetiva.
"""

user_prompt = """
Uma empresa de moda quer lançar uma campanha para atrair a Geração Z.
Dados:
- Orçamento: R$ 500 mil
- Principais canais: Instagram, TikTok, YouTube
- Objetivo: aumentar vendas online em 30% em 6 meses
- Concorrência: 3 marcas fortes no mesmo segmento

Crie um plano de campanha explicando o raciocínio passo a passo.
"""

response = client.chat.completions.create(
    model="openai/gpt-oss-120b",
    messages=[{"role": "developer", "content": system_prompt},
           {"role": "user", "content": user_prompt}],
    temperature=0.4
)

print("Plano de Marketing:", response.choices[0].message.content)
# Out:
# Plano de Marketing: <cot>
# 1. **Entender o público da Geração Z**
#    - Idade: 16‑24 anos.
#    - Valores: autenticidade, inclusão, sustentabilidade, rapidez e conteúdo visualmente impactante.
#    - Consumo de mídia: alta presença no Instagram (feed + Stories/Reels), TikTok (short‑form) e YouTube (conteúdo mais longo e “how‑to”).
#    - Decisão de compra: influenciada por criadores, reviews de produtos e provas sociais.
#
# 2. **Analisar o orçamento (R$ 500 mil) e alocação eficiente**
#    - Produção de conteúdo criativo: 30 % (R$ 150 k).
#    - Influenciadores micro‑ e macro‑influencers: 35 % (R$ 175 k).
#    - Mídia paga (ads, boost, TikTok Spark Ads): 25 % (R$ 125 k).
#    - Ferramentas de análise, testes A/B e reserva de contingência: 10 % (R$ 50 k).
#
# 3. **Mapear a jornada de compra**
#    - **Descoberta** → Reels/TikTok virais, anúncios in‑feed.
#    - **Consideração** → Reviews de influenciadores, “try‑on” no YouTube, “Swipe‑up” para página de produto.
#    - **Conversão** → Links rastreáveis, códigos de desconto exclusivos, checkout otimizado mobile.
#    - **Fidelização** → UGC (User‑Generated Content), challenges, programa de recompensas.
#
# 4. **Definir pilares criativos**
#    - **Autenticidade & Inclusão**: modelos reais, diversidade de corpos e estilos.
#    - **Sustentabilidade**: destacar materiais eco‑friendly, processos de produção.
#    - **Interatividade**: challenges TikTok, filtros AR no Instagram, “duetos” com influenciadores.
#    - **Storytelling de “Look do Dia”**: vídeos curtos mostrando combinações rápidas.
#
# 5. **Escolher influenciadores**
#    - **Macro (100 k‑500 k seguidores)**: 2‑3 criadores para alcance amplo, custo médio R$ 30 k cada.
#    - **Micro (10 k‑100 k seguidores)**: 10‑12 criadores nichados (fashion, streetwear, sustainability) – custo médio R$ 5 k cada.
#    - **Nano (≤10 k)**: incentivar UGC com recompensas (descontos, produtos grátis) – custo baixo, alto engajamento.
#
# 6. **Planejar cronograma de 6 meses**
#    - **Mês 1‑2 (Lançamento)**: teaser teaser, challenge TikTok “#MeuEstiloZ”, anúncios de awareness, primeiros posts de macro‑influencers.
#    - **Mês 3‑4 (Consideração)**: reviews detalhados no YouTube, “look‑book” em Reels, retargeting de quem interagiu nos primeiros 2 meses.
#    - **Mês 5‑6 (Conversão & Fidelização)**: códigos de desconto limitados, “flash sales” ao vivo no Instagram, concurso de UGC com prêmio de guarda‑roupa completo.
#
# 7. **Métricas de sucesso (KPIs)**
#    - **Awareness**: Reach e Impressions nas plataformas (meta 5 M reach total).
#    - **Engajamento**: Taxa de engajamento > 8 % nos Reels/TikTok, número de UGC criados.
#    - **Conversão**: ROAS ≥ 3, aumento de vendas online 30 % em 6 meses.
#    - **Retenção**: % de compradores que retornam em 30 dias, crescimento da base de e‑mail.
#
# 8. **Teste e otimização**
#    - A/B testing de criativos (cores, chamadas, formatos).
#    - Ajuste de budget entre Instagram e TikTok com base no CPA (cost per acquisition).
#    - Análise semanal de dashboards para realocar recursos rapidamente.
#
# 9. **Riscos e mitigação**
#    - **Saturação de anúncios** → foco em conteúdo orgânico e UGC.
#    - **Crise de reputação** → monitoramento de comentários, resposta rápida, política de transparência.
#    - **Concorrência** → diferenciação por valores (sustentabilidade, inclusão) e formatos exclusivos (AR filter).
#
# 10. **Retorno esperado**
#     - Com um CAC médio de R$ 100 e ticket médio de R$ 250, o aumento de 30 % nas vendas (aprox. 150 k unidades) gera receita adicional de ~R$ 37,5 mi, superando o investimento de R$ 500 k e proporcionando ROI > 70 x.
# </cot>
#
# **Conclusão objetiva:**
# Alocar 30 % do orçamento em produção de conteúdo autêntico, 35 % em influenciadores (macro + micro) e 25 % em mídia paga, estruturando a campanha em três fases (awareness, consideração, conversão) ao longo de 6 meses, com foco em challenges TikTok, Reels/Stories interativos e reviews no YouTube. Monitorar KPIs de reach, engajamento, CPA e ROAS para otimizar continuamente. Essa estratégia deve gerar o aumento de 30 % nas vendas online dentro do prazo e garantir um ROI robusto.

# %% [markdown]
# ### Cot em Saúde
# - Apoio em raciocínio clínico

# %%
system_prompt = """
Você é um médico que usa Chain of Thoughts (CoT) para raciocínio clínico.
Sempre apresente hipóteses dentro de <cot> e finalize com recomendação objetiva.
"""

user_prompt = """
Paciente: 45 anos, sedentário, fumante, apresenta dores no peito durante esforço físico.
Exames iniciais: colesterol alto, pressão arterial elevada.

Qual deve ser a recomendação inicial para o paciente?
"""

response = client.chat.completions.create(
    model="openai/gpt-oss-120b",
    messages=[{"role": "developer", "content": system_prompt},
           {"role": "user", "content": user_prompt}],
    temperature=0.5
)

print("Análise clínica:", response.choices[0].message.content)
# Out:
# Análise clínica: **Raciocínio clínico (Chain of Thoughts)**
#
# <cot>
# 1. **Hipótese de doença arterial coronariana (DAC) – angina estável**
#    - Dor torácica desencadeada por esforço físico → sugestiva de isquemia miocárdica.
#    - Fatores de risco presentes: idade > 40 anos, tabagismo, sedentarismo, hipertensão arterial e hipercolesterolemia.
#
# 2. **Hipótese de doença arterial periférica ou esofágica**
#    - Embora menos provável, dores torácicas podem ser referidas de outras estruturas; porém a relação com esforço favorece DAC.
#
# 3. **Hipótese de hipertensão mal controlada com dor torácica por sobrecarga cardíaca**
#    - Pressão arterial elevada pode causar dor torácica em esforço, mas geralmente acompanha outros sinais de sobrecarga.
#
# **Conclusão do CoT:** A combinação de dor torácica de esforço + múltiplos fatores de risco cardiovasculares indica fortemente a necessidade de avaliação para DAC e, simultaneamente, controle agressivo dos fatores de risco.
# </cot>
#
# **Recomendação objetiva para o paciente**
#
# 1. **Interromper o tabagismo imediatamente** – encaminhar para programa de cessação (consulta de pneumologia ou clínica de cessação, uso de NRT ou vareniclina, apoio psicológico).
# 2. **Iniciar mudanças no estilo de vida**
#    - Dieta DASH ou mediterrânea: reduzir gorduras saturadas, aumentar frutas, legumes, fibras.
#    - Atividade física gradual: após avaliação cardiológica, iniciar caminhada leve 3‑5 vezes/semana, progredindo conforme tolerância.
# 3. **Controle da pressão arterial**
#    - Iniciar tratamento farmacológico (ex.: inibidor da enzima conversora de angiotensina ou bloqueador dos canais de cálcio) visando < 130/80 mmHg, conforme diretrizes.
# 4. **Controle do colesterol**
#    - Iniciar estatina de alta intensidade (ex.: atorvastatina 40‑80 mg ou rosuvastatina 20‑40 mg) para reduzir LDL‑c < 70 mg/dL.
# 5. **Avaliação cardiológica urgente**
#    - Agendar teste ergométrico ou teste de esforço com imagem (ecocardiograma ou cintilografia) para confirmar isquemia.
#    - Se houver evidência de DAC significativa, considerar encaminhamento para cardiologia intervencionista (angiografia coronariana).
# 6. **Educação e acompanhamento**
#    - Agendar consulta de retorno em 4‑6 semanas para revisão de pressão, colesterol, adesão ao tratamento e ajuste de medicação.
#
# **Resumo:** Parar de fumar, iniciar dieta e exercício, iniciar estatina + anti‑hipertensivo e solicitar avaliação de isquemia (teste de esforço). Esses passos reduzem o risco imediato de eventos cardíacos e permitem diagnóstico definitivo.

# %% [markdown]
# ### Cot em Análise de Investimentos
# - Avaliação de riscos e oportunidades

# %%
system_prompt = """
Você é um consultor financeiro que usa Chain of Thoughts (CoT).
Mostre seu raciocínio dentro de <cot> e termine com uma recomendação objetiva.
"""

user_prompt = """
Uma startup de tecnologia está levantando R$ 5 milhões.
Dados:
- Receita atual: R$ 300 mil/mês
- Crescimento: 12% ao mês
- Equipe: 20 pessoas
- Concorrência: forte no mercado nacional
- Risco: dependência de um único grande cliente

Devo recomendar o investimento?
"""

response = client.chat.completions.create(
    model="openai/gpt-oss-120b",
    messages=[{"role": "developer", "content": system_prompt},
           {"role": "user", "content": user_prompt}],
    temperature=0.4
)

print("Recomendação de investimento:", response.choices[0].message.content)
# Out:
# Recomendação de investimento: <cot>
# **1. Análise da Receita e Crescimento**
# - Receita atual: R$ 300 mil/mês → R$ 3,6 mi/ano.
# - Crescimento de 12 % ao mês equivale a aproximadamente 2,9 × ao ano ( (1,12)^12 ≈ 3,1 ).
# - Projeção de receita anual em 12 meses:
#   - Mês 1: R$ 300 k × 1,12 = R$ 336 k
#   - Mês 12: R$ 300 k × (1,12)^12 ≈ R$ 936 k
#   - Receita total no primeiro ano ≈ R$ 5,6 mi.
#
# **2. Runway com o aporte de R$ 5 mi**
# - Custos mensais (estimados):
#   - Salários (20 pessoas, média R$ 8 k): R$ 160 k
#   - Despesas operacionais (infra, marketing, etc.): ~R$ 40 k
#   - Total ≈ R$ 200 k/mês → R$ 2,4 mi/ano.
# - Com a nova receita projetada (≈ R$ 5,6 mi/ano) e custos de R$ 2,4 mi, o EBITDA esperado seria ~R$ 3,2 mi/ano, indicando capacidade de gerar caixa positivo já no primeiro ano.
# - O aporte de R$ 5 mi aumentaria o runway para cerca de 30 meses, permitindo investimento em expansão de vendas e diversificação de clientes.
#
# **3. Avaliação de risco**
# - **Cliente único**: Concentração de receita >50 % em um único cliente eleva risco de churn. Necessário plano de aquisição de novos clientes dentro dos próximos 12‑18 meses.
# - **Concorrência forte**: O mercado nacional tem players consolidados; a startup precisa de diferenciação (tecnologia proprietária, barreiras de entrada, patentes ou rede de parceiros).
# - **Equipe**: 20 pessoas é tamanho adequado para a fase atual, mas a estrutura de liderança (CEO, CFO, CTO, vendas) deve ser robusta para escalar.
#
# **4. Valuation implícita**
# - Se o investidor aportar R$ 5 mi por, digamos, 20 % do equity, a pós‑money valuation seria R$ 25 mi.
# - Considerando a projeção de receita de R$ 5,6 mi no próximo ano e um múltiplo de receita de 4‑5× (padrão para SaaS de alto crescimento), a valuation de R$ 25 mi parece razoável, porém levemente otimista dado o risco de cliente único.
#
# **5. Estratégia de mitigação**
# - Destinar parte do capital (≈ R$ 1 mi) para programa de aquisição de clientes (marketing, vendas outbound).
# - Investir em desenvolvimento de produto para criar funcionalidades que aumentem o “lock‑in” dos clientes atuais e facilitem a entrada em novos segmentos.
# - Criar um plano de contingência caso o cliente principal reduza o contrato (ex.: reserva de caixa de 6‑12 meses).
#
# **6. Decisão**
# - Pontos positivos: crescimento rápido, margem bruta alta, runway suficiente, valuation alinhada ao mercado.
# - Pontos negativos: alta dependência de um cliente e competição intensa, que podem comprometer a sustentabilidade se não houver diversificação rápida.
#
# Conclusão: O investimento é atrativo **desde que** o acordo inclua cláusulas de governança (board seat, veto em decisões estratégicas) e um plano claro de diversificação de clientes nos primeiros 12‑18 meses. Caso essas condições não sejam atendidas, o risco pode superar o potencial de retorno.
# </cot>
#
# **Recomendação objetiva:**
# Recomendo **aprovar o investimento**, condicionando-o à implementação de um plano de aquisição de novos clientes e a inclusão de mecanismos de governança que protejam o investidor contra a concentração de risco.

# %% [markdown]
# ### Cot em Design de Produto
# - Raciocínio para priorização de funcionalidades

# %%
system_prompt = """
Você é um Product Manager que usa Chain of Thoughts (CoT).
Mostre o raciocínio dentro de <cot> e finalize com a priorização.
"""

user_prompt = """
Estamos desenvolvendo um aplicativo de bem-estar.
Funcionalidades propostas:
1. Meditação guiada
2. Monitoramento de sono
3. Gamificação de hábitos
4. Relatórios personalizados

Orçamento permite lançar apenas duas no MVP.
Qual priorizar?
"""

response = client.chat.completions.create(
    model="openai/gpt-oss-120b",
    messages=[{"role": "developer", "content": system_prompt},
           {"role": "user", "content": user_prompt}],
    temperature=0.3
)

print("Funcionalidades prioritárias:", response.choices[0].message.content)
# Out:
# Funcionalidades prioritárias: <cot>
# **1. Entender o objetivo do MVP**
# - Validar a proposta de valor central do app de bem‑estar.
# - Gerar engajamento rápido e coletar dados de uso para iterar.
# - Manter o escopo pequeno para entregar dentro do orçamento e do prazo.
#
# **2. Avaliar cada funcionalidade**
#
# | Funcionalidade | Valor para o usuário (impacto) | Complexidade / esforço de desenvolvimento | Sinergia com outras features | Potencial de diferenciação |
# |----------------|--------------------------------|-------------------------------------------|------------------------------|----------------------------|
# | Meditação guiada | Alto – solução já conhecida, fácil de adotar, gera retenção diária. | Médio – gravações, player, playlists, UI simples. | Pode alimentar relatórios personalizados e gamificação (pontos por sessões). | Moderado – mercado competitivo, mas ainda há espaço para nichos (ex.: foco em ansiedade). |
# | Monitoramento de sono | Alto – dado valioso, aumenta percepção de saúde, gera insights. | Alto – integração com sensores, análise de dados, UI de gráficos. | Alimenta relatórios personalizados e pode gerar recompensas na gamificação. | Alto – poucos apps de bem‑estar oferecem monitoramento preciso sem hardware dedicado. |
# | Gamificação de hábitos | Médio – aumenta engajamento, mas depende de conteúdo de hábitos já existentes. | Médio/Alto – sistema de pontos, níveis, recompensas, backend de tracking. | Complementa meditação e sono, mas pode ser implementado depois. | Moderado – pode ser diferencial, porém exige design cuidadoso. |
# | Relatórios personalizados | Médio/Alto – entrega valor percebido, ajuda a reter usuários ao mostrar progresso. | Alto – necessidade de analytics, visualizações, personalização. | Depende de dados coletados (sono, meditação, hábitos). | Moderado – muitos apps oferecem relatórios básicos; a personalização pode ser um diferencial, mas requer dados. |
#
# **3. Priorizar pelo critério “alto impacto + esforço moderado”**
# - **Meditação guiada**: entrega valor imediato, esforço controlado, gera engajamento diário e fornece dados (número de sessões) que podem ser usados nos relatórios futuros.
# - **Monitoramento de sono**: apesar do esforço maior, traz um conjunto de dados rico que diferencia o app e permite criar relatórios personalizados e bases para gamificação. Além disso, o sono é uma das áreas mais críticas para bem‑estar, aumentando a atratividade do produto.
#
# **4. Verificar risco de dependência**
# - Relatórios personalizados precisam de dados; ao escolher meditação + sono já temos duas fontes de dados suficientes para gerar relatórios simples no futuro, sem precisar lançá‑los no MVP.
# - Gamificação pode ser adicionada depois, usando os mesmos eventos de meditação e sono como gatilhos de recompensas.
#
# **5. Conclusão**
# As duas funcionalidades que melhor equilibram valor ao usuário, viabilidade de entrega e potencial de diferenciação são **Meditação guiada** e **Monitoramento de sono**. Elas permitem validar a proposta de bem‑estar, gerar engajamento diário e coletar dados críticos para evoluções posteriores (relatórios e gamificação).
# </cot>
#
# **Prioridade para o MVP (duas funcionalidades):**
# 1️⃣ Meditação guiada
# 2️⃣ Monitoramento de sono

# %%
# Chain of Thoughts
cot_prompt = """
Quais as vantagens de trabalhar remoto? 
Use Chain of Thoughts para pensar passo a passo antes de responder.
"""

response_cot = client.chat.completions.create(
    model="openai/gpt-oss-120b",
    messages=[{"role": "user", "content": cot_prompt}],
    temperature=0.5
)

print("=== CHAIN OF THOUGHTS ===")
print(response_cot.choices[0].message.content)
# Out:
# === CHAIN OF THOUGHTS ===
# **Raciocínio passo a passo (Chain of Thoughts)**
#
# 1. **Identificar os principais aspectos da vida profissional que podem ser impactados por um modelo remoto.**
#    - Horário e flexibilidade.
#    - Deslocamento e custos associados.
#    - Ambiente de trabalho e conforto.
#    - Produtividade e foco.
#    - Equilíbrio entre vida pessoal e profissional.
#    - Acesso a oportunidades e diversidade geográfica.
#    - Impacto ambiental e social.
#
# 2. **Analisar como cada aspecto se transforma quando o trabalho é realizado à distância.**
#    - **Flexibilidade de horário:** sem a necessidade de cumprir um “ponto” rígido, o colaborador pode adaptar o expediente às suas necessidades pessoais (ex.: cuidar de filhos, fazer exercícios).
#    - **Eliminação do deslocamento:** menos tempo perdido no trânsito ou em transportes públicos, reduzindo estresse e custos (combustível, passagem, alimentação fora de casa).
#    - **Ambiente personalizado:** o profissional pode montar um espaço de trabalho que atenda às suas preferências (cadeira ergonômica, iluminação, música).
#    - **Aumento de produtividade:** a diminuição de interrupções típicas de um escritório (conversas paralelas, reuniões presenciais desnecessárias) pode favorecer foco e entrega de resultados.
#    - **Melhor equilíbrio vida‑trabalho:** a proximidade com a família e a possibilidade de conciliar tarefas domésticas contribuem para maior satisfação pessoal.
#    - **Acesso a talentos e oportunidades globais:** empresas podem contratar profissionais de qualquer lugar, e os trabalhadores podem buscar vagas que antes estavam limitadas à sua cidade.
#    - **Redução da pegada de carbono:** menos deslocamentos diários e menos uso de recursos físicos (papel, energia de grandes escritórios) trazem benefícios ambientais.
#
# 3. **Consolidar as ideias em categorias claras para facilitar a compreensão.**
#
# ---
#
# ## Vantagens de trabalhar remotamente
#
# ### 1. Flexibilidade de horário
# - Possibilidade de ajustar o início/fim da jornada conforme a rotina pessoal.
# - Facilita a realização de atividades extracurriculares (cursos, hobbies, cuidados familiares).
#
# ### 2. Economia de tempo e dinheiro
# - Elimina o tempo gasto no deslocamento (geralmente de 30 min a 2 h por dia).
# - Reduz custos com transporte, alimentação fora de casa, vestuário formal, etc.
#
# ### 3. Conforto e personalização do ambiente
# - O colaborador pode montar um home office ergonomicamente adequado ao seu estilo.
# - Menos distrações típicas de um escritório aberto (conversas paralelas, ruídos).
#
# ### 4. Aumento de produtividade e foco
# - Maior autonomia para organizar tarefas e priorizar entregas.
# - Ferramentas digitais permitem monitoramento de progresso sem a necessidade de supervisão constante.
#
# ### 5. Melhor equilíbrio entre vida pessoal e profissional
# - Proximidade com a família e possibilidade de participar de eventos domésticos.
# - Redução do estresse associado ao “ciclo do trânsito” e ao ambiente corporativo tradicional.
#
# ### 6. Acesso a oportunidades globais
# - Empresas podem contratar talentos independentemente da localização geográfica.
# - Profissionais têm acesso a vagas que antes exigiam mudança de cidade ou país.
#
# ### 7. Impacto ambiental positivo
# - Menos deslocamentos diários diminui emissões de CO₂.
# - Redução do consumo de energia e recursos em grandes escritórios.
#
# ### 8. Inclusão e diversidade
# - Pessoas com mobilidade reduzida, cuidadores ou residentes em áreas remotas podem participar do mercado de trabalho formal.
# - Amplia a diversidade de perspectivas dentro das equipes.
#
# ### 9. Resiliência organizacional
# - Estruturas de trabalho remoto bem implementadas permitem que a empresa continue operando em situações de crise (pandemias, desastres naturais, etc.).
#
# ---
#
# ### Resumindo
# Trabalhar remotamente traz benefícios que vão além da simples “comodidade”: promove flexibilidade, economia, maior produtividade, equilíbrio pessoal, acesso a talentos globais e ainda contribui para a sustentabilidade ambiental e social. Cada organização deve avaliar como adaptar essas vantagens ao seu modelo de negócios, garantindo que a cultura e a comunicação sejam mantidas mesmo à distância.
