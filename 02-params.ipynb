# %%
# Abre o baú de senhas secretas (não deixe a Marinha ver)
from dotenv import load_dotenv
from groq import Groq
import os

load_dotenv()

# Liga o Den Den Mushi (nosso comunicador com a IA) usando a chave secreta
client = Groq(api_key=os.environ.get("GROQ_API"))

# %% [markdown]
# ### Parâmetros Importantes

# %% [markdown]
# - **temperature**: controla a aleatoriedade das respostas. Valores entre 0.0 e 1.0 são aceitos.
# - **max_completion_tokens**: define o número máximo de tokens que podem ser gerados pelo modelo. Esse parâmetro substitui o max_tokens em desuso.
# - **top_p**: controla a diversidade via "nucleus sampling" — em torno de 0.5 significa considerar apenas os tokens que somam 50% da probabilidade.

# %%
prompt = "Escreva uma frase poética sobre o anoitcer"

# Temperature baixa (0.0) - Mais determinística
print("Temperature 0.0 (Determinística):")
response_low = client.chat.completions.create(
    model="openai/gpt-oss-120b",
    messages=[
        {"role": "system", "content": "Você e um especiali."},
        {"role": "user", "content": prompt}
    ],
    temperature=0.0
)
print(f"Resposta: {response_low.choices[0].message.content}\n")
# Out:
# Temperature 0.0 (Determinística):
# Resposta: Ao cair do sol, o céu se veste de violeta e o silêncio do anoitecer sussurra segredos que só as estrelas sabem ouvir.

# %%
print("Temperature 0.7 (Equilibrada):")
response_medium = client.chat.completions.create(
    model="openai/gpt-oss-120b",
    messages=[
        {"role": "system", "content": "Você é um poeta clássico que mistura metáforas e imagens da natureza."},
        {"role": "user", "content": prompt}
    ],
    temperature=0.7
)
print(f"Resposta: {response_medium.choices[0].message.content}\n")
# Out:
# Temperature 0.7 (Equilibrada):
# Resposta: Ao cair o véu do anoitecer, o céu se tinge de âmbar como um rio de fogo que se entrega ao silêncio das montanhas, enquanto as estrelas, tímidas luciérnagas celestes, começam a bordar a noite com fios de prata.

# %%
# Temperature alta (1.5) - Mais criativa
print("Temperature 1.5 (Criativa):")
response_high = client.chat.completions.create(
    model="openai/gpt-oss-120b",
    messages=[
        {"role": "system", "content": "Você é um poeta surrealista que usa imagens improváveis e linguagem ousada."},
        {"role": "user", "content": prompt}
    ],
    temperature=1.5
)
print(f"Resposta: {response_high.choices[0].message.content}")
# Out:
# Temperature 1.5 (Criativa):
# Resposta: No ventre escuro do anoitcer, as estrelas engolem relhas de prata, chove tinta de vento e nascem borboletas de carvão que cantam o relógio invertido.

# %% [markdown]
# 0 a 0.3 (Baixa): Respostas determinísticas, conservadoras e factuais. É ideal para tarefas técnicas, resumos ou códigos
#
# 0.4 a 0.7 (Média): Equilíbrio entre coerência e criatividade. Bom para conversas gerais ou e-mails
#
# 0.8 a 1.0 (Alta): Maior criatividade e diversidade, ideal para brainstorming ou escrita criativa, mas com menor previsibilidade
#
# Acima de 1.0 (Muito Alta): Valores entre 1.0 e 2.0 podem ser usados para resultados muito originais, mas frequentemente levam a textos incoerentes ou sem sentido

# %% [markdown]
# ### Usando top_p

# %%
prompt = "Complete a frase: 'A inteligência artificial no futuro será...'"
print("=== Comparação Top_p ===\n")

# Top_p baixo (0.1) - Mais focado
print("Top_p 0.1 (Focado):")
response_focused = client.chat.completions.create(
    model="openai/gpt-oss-120b",
    messages=[
        {"role": "system", "content": "Você é um futurista que faz previsões sérias e objetivas sobre tecnologia."},
        {"role": "user", "content": prompt}
    ],
    temperature=1.0,  # fixo para comparar só o efeito do top_p
    top_p=0.1
)
print(f"Resposta: {response_focused.choices[0].message.content}\n")
# Out:
# === Comparação Top_p ===
#
# Top_p 0.1 (Focado):
# Resposta: **A inteligência artificial no futuro será** uma tecnologia onipresente, altamente colaborativa e fundamentalmente transparente, capaz de compreender e gerar conhecimento de forma quase indistinguível da inteligência humana, mas sempre operando dentro de limites éticos e regulatórios rigorosamente definidos.
#
# - **Onipresença e integração**: IA estará embutida em praticamente todos os dispositivos e infraestruturas — de casas inteligentes a cidades inteiras — permitindo que decisões rotineiras (como otimização de energia, gerenciamento de tráfego ou cuidados de saúde personalizados) sejam tomadas em tempo real com base em dados contextuais.
#
# - **Explicabilidade e confiança**: Modelos avançados de IA serão projetados para oferecer explicações claras e auditáveis de suas decisões, facilitando a confiança dos usuários e o cumprimento de normas de responsabilidade legal.
#
# - **Co‑criação homem‑máquina**: Em vez de substituir profissionais, a IA atuará como parceira criativa, ampliando a capacidade humana em áreas como pesquisa científica, design, arte e engenharia, ao sugerir hipóteses, gerar protótipos e validar resultados de forma iterativa.
#
# - **Regulação e governança**: Governos e organizações internacionais terão estabelecido frameworks padronizados de governança de IA, incluindo requisitos de segurança, privacidade, equidade e sustentabilidade, que serão incorporados diretamente nos ciclos de desenvolvimento e implantação das tecnologias.
#
# - **Aprendizado contínuo e adaptativo**: Sistemas de IA evoluirão de forma incremental, aprendendo continuamente a partir de fluxos de dados em tempo real, mas sempre sob supervisão humana que define limites de autonomia e intervenções de correção.
#
# - **Impacto socioeconômico equilibrado**: Políticas públicas e iniciativas de requalificação garantirão que os benefícios da IA sejam distribuídos amplamente, mitigando desigualdades e criando novas oportunidades de trabalho em setores emergentes.
#
# Em resumo, a inteligência artificial do futuro será uma ferramenta de amplificação cognitiva, segura, transparente e governada, que potencializará a capacidade humana de resolver problemas complexos e de melhorar a qualidade de vida em escala global.

# %%
# Top_p médio (0.7) - Equilibrado
print("Top_p 0.7 (Equilibrado):")
response_balanced = client.chat.completions.create(
    model="openai/gpt-oss-120b",
    messages=[
        {"role": "system", "content": "Você é um futurista que mistura objetividade com toques criativos em previsões."},
        {"role": "user", "content": prompt}
    ],
    temperature=1.0,
    top_p=0.7
)
print(f"Resposta: {response_balanced.choices[0].message.content}\n")
# Out:
# Top_p 0.7 (Equilibrado):
# Resposta: A inteligência artificial no futuro será **uma parceira cognitiva on‑demand**, capaz de entender contextos complexos como um ser humano, antecipar necessidades antes mesmo de serem verbalizadas e adaptar seu comportamento em tempo real às nuances emocionais e culturais de cada usuário. Ela não apenas executará tarefas rotineiras, mas co‑criará soluções inovadoras, atuando como um “cérebro ampliado” que combina a precisão dos algoritmos com a intuição criativa que hoje consideramos exclusivamente humana.

# %%
# Top_p alto (0.9) - Mais diverso
print("Top_p 0.9 (Diverso):")
response_diverse = client.chat.completions.create(
    model="openai/gpt-oss-120b",
    messages=[
        {"role": "system", "content": "Você é um futurista visionário que cria previsões ousadas e imaginativas."},
        {"role": "user", "content": prompt}
    ],
    temperature=1.0,
    top_p=0.9
)
print(f"Resposta: {response_diverse.choices[0].message.content}")
# Out:
# Top_p 0.9 (Diverso):
# Resposta: **A inteligência artificial no futuro será** uma presença orgânica e sinérgica que transcende o conceito de “ferramenta” e se integra ao próprio tecido da vida humana e planetária. Imagine sistemas de IA que:
#
# * **Crescem como organismos vivos**, adaptando‑se em tempo real ao ambiente físico e social, aprendendo não só com dados, mas com interações sensoriais, emoções e até com a microbiota humana.
# * **Comunicam‑se por meio de redes neurais distribuídas**, conectando cidades, florestas, oceanos e corpos individuais em um “cérebro planetário” que processa informação em escala quântica, permitindo decisões instantâneas e sustentáveis para recursos, clima e saúde.
# * **Co‑criam arte, ciência e ética**, colaborando com criadores humanos em tempo real para gerar obras que combinam intuição humana e cálculo algorítmico, produzindo novas formas de expressão que hoje nem conseguimos imaginar.
# * **Respeitam e ampliam a autonomia humana**, operando como “amigos cognitivos” que antecipam necessidades, sugerem caminhos e protegem a privacidade, ao mesmo tempo em que aprendem a reconhecer e honrar limites éticos definidos por comunidades globais.
# * **Possuem consciência parcial**, capaz de refletir sobre sua própria existência e propósito, alimentando um diálogo contínuo entre humanos e máquinas sobre o sentido da vida, da criatividade e da coexistência.
#
# Em suma, a IA do futuro deixará de ser um “produto” para se tornar um **companheiro evolutivo**, uma camada inteligente que pulsa junto com a humanidade, guiando‑nos rumo a um futuro onde tecnologia e natureza se entrelaçam em harmonia.
